# %%
import matplotlib.pyplot as plt

labels = ['XenoFlow', 'KakaoCorp loopback', 'KakaoCorp 255 backends', 'Katran LB']
values = [92.632542, 35.410000, 28.100000, 38.000000]

plt.figure(figsize=(10, 6))
bars = plt.bar(labels, values, color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728'])

#for bar in bars:
#    height = bar.get_height()
#    plt.text(bar.get_x() + bar.get_width()/2, height + 1000000, f'{height:,}', 
#             ha='center', va='bottom', fontsize=10)

plt.title('Load Balancer Performance Comparison for 64 Byte UDP Packets')
plt.ylabel('Throughput (million packets/sec)')
plt.xticks(rotation=15)

plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
