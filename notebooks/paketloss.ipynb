# %%
import matplotlib.pyplot as plt

x = [0, 15_000_000, 30_000_000, 45_000_000, 60_000_000, 75_000_000, 90_000_000, 105_000_000, 120_000_000]
y = [0, 0, 0, 0, 0, 0, 0, 0, 0]
plt.figure(figsize=(10, 6))
plt.grid(True)
plt.plot(x, y, "-s", label="RTT Latency")
plt.title("Relationship Between LB Load and Paketloss")
plt.xlabel("Packets/s Baseload")
plt.xticks(x, [str(int(val/1_000_000)) + " Mio." for val in x], rotation=45)
plt.ylabel("Paketloss in %")
plt.legend()
plt.show()
